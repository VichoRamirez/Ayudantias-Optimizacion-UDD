# %% [markdown]
# ## IIP314W Optimización aplicada a negocios
#
# Metodo Simplex - Ejercicios Dual + sensibilidad

# %% [markdown]
# #### Primal:
#
# $$ mín \quad c^T \cdot x $$
#
# sujeto a,
#
# $$ A \cdot x \le b $$
#
# $$ x_i \ge 0 $$
#
# #### Dual
#
# $$ max \quad b^T \cdot y $$
#
# sujeto a,
#
# $$ A^T \cdot y \ge c $$
#
# $$ y_i \ge 0 $$

# %% [markdown]
# ### Ejercicio 19
#
# Aprovechando la oportunidad del aumento de consumo en invierno, un distribuidor de gas envasado ha decidido ofrecer *paquetes de oferta* por varios balones a los clientes institucionales de su zona. En este sentido, a lanzado a la venta sus promociones *super65* y *extra170* que consisten en las siguientes combinaciones de balones:
#
# - Super65 : un balón de 5kg, un balón de 15kg y un cilindro de 45kg.
# - Extra170 : un balón de 5kg, dos balones de 15kg y tres cilindros de 45kg.
#
# El distribuidor ha dispuesto que se utilizarían a lo más, 40 balones de 5kg, 50 balones de 15kg y 66 cilindros de 45kg para estas promociones. De acuerdo al precio que ha fijado para las promociones, el beneficio por cada *super65* es de 10 mil pesos y por cada promoción *extra170* el beneficio es de 24 mil pesos. Para determinar cuántas promociones de cada tipo debe ofrecer de manera de maximizar el beneficio obtenido, se planteó el siguiente modelo de programación lineal **Q**:
#
# $$máx \quad 10 x_1 + 24 x_2$$
#
# sujeto a,
#
# $$x_1 + x_2 \le 40$$
# $$x_1 + 2x_2 \le 50$$
# $$x_1 + 3x_2 \le 66$$
# $$x1, x2 \ge 0$$
#
# Resolviendo este modelo, se determinó que en la producción óptima (que corresponde a una solución básica factible de **Q**) se ofrece una cantidad positiva de ambos tipos de promoción y se obtiene un beneficio total de 564 miles de pesos. Ahora, el responsable de las promociones está analizando la posibilidad de destinar más balones y cilindros y desea ver cúal es el valor marginal de éstos cuando se usan para las promociones. Para esto, debe resolver el problema dual del modelo **Q**.
#
# a. (10 puntos) Plantee este problema dual.
#
# b. (20 puntos) Encuentre una solución óptima del problema dual planteado en el punto anterior.
#
# c. (10 puntos) Como parte del estudio, se quiere determinar las cantidades apropiadas de balones y cilindros destinadas a las promociones de acuerdo a las necesidades comerciales. ¿Hasta qué cantidad podría disminuir la disponibilidad de balones de 15kg para que la combinación de promociones obtenida con el modelo **Q** se mantenga óptima?

# %%
# Respuestas
# b. 0,6,4
# c. 44

# %% [markdown]
# ### Ejercicio 20
#
# Una pequeña empresa de alimentos desea planificar la producción de frutas en conserva para la temporada estival que se acerca. Durante el verano, la empresa produce principalmente duraznos y cerezas en conserva. En el proceso productivo de la empresa hay dos etapas en que los recursos son más limitados.
#
# En un primer paso, la fruta fresca recibida de los productores debe ser revisada y clasificada. Cada tonelada de durazno requiere una hora de este proceso, mientras que para cada tonelada de cerezas se utilizan dos horas. La empresa dispone semanalmente de 80 horas para este proceso. Luego de esto, la fruta pasa por un proceso de despalillado y lavado. La empresa cuenta con recursos para 180 horas de este trabajo. Cada tonelada de duraznos utiliza 5 horas, mientras que para cada tonelada de cerezas se requieren 3 horas de este proceso. Una vez finalizado el procesamiento y envasado de la fruta, esta debe ser almacenada en la bodega antes de ser enviada al distribuidor. La empresa cuenta con una bodega con capacidad para recibir semanalmente hasta 45 toneladas de fruta en total. La empresa obtiene un beneficio de 30 mil pesos por tonelada producida de duraznos y de 40 mil pesos, por tonelada de cerezas.
#
# Para determinar las cantidades de cada fruta a procesar por semana que maximizan el beneficio obtenido, se planteó el siguiente modelo de programación lineal **P**:
#
# $$máx \quad 30x_1 + 40x_2$$
#
# sujeto a,
#
# $$x_1 + 2x_2 \le 80$$
# $$5x_1 + 3x_2 \le 180$$
# $$x_1 + x_2 \le 45$$
# $$x_1, x_2 \ge 0$$
#
# donde $x_1$ y $x_2$ son las toneladas de duraznos y cerezas, respectivamente, a procesar por semana y la función objetivo está escrita en miles de pesos.
#
# Resolviendo este modelo, se determinó que en la producción óptima (que corresponde a una solución básica factible de **P**) se procesa una cantidad positiva de ambos tipos de fruta y no se utiliza completamente el tiempo disponible para despalillado y lavado. Ahora, el responsable de las planificación de la producción está analizando la posibilidad de ampliar los recursos destinados a estos productos y desea entender cuál es su valor marginal para la empresa. Para esto, debe resolver el problema dual del modelo **P**.
#
# a. (5 puntos) Plantee este problema dual.
#
# b. (15 puntos) Encuentre una solución óptima del problema dual planteado en el punto anterior.
#
# c. (10 puntos) Como parte del estudio, se quiere entender si los tiempos disponibles para los procesos son los apropiados. ¿En qué rango de valores para la disponibilidad de tiempo de revisión y clasificación (primer proceso) el plan de producción de la empresa es óptimo?
#
# d. (10 puntos) Finalmente, se está revisando la estructura de costos y precios de venta, lo que podría modificar el valor de los beneficios de la empresa. ¿Para qué rango de valores para el beneficio por tonelada de duraznos, el plan de producción de la empresa es óptimo?

# %%
# Respuestas
# b. 10, 0, 20
# c. entre 62.5 y 90
# d. entre 20 mil y 40 mil.
