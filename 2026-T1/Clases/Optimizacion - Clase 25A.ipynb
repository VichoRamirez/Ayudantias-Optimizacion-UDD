# %% [markdown]
# ## IIP314W Optimización aplicada a negocios
#
# Algoritmo simplex, repaso certamen 2

# %% [markdown]
# ### Ejercicio 24
#
# Considere el problema de optimización
#
# $$máx \quad 𝑥_1+3𝑥_2$$
#
# sujeto a,
#
# $$5𝑥_1+2𝑥_2\ge30$$
# $$3𝑥_1−2𝑥_2\le18$$
# $$𝑥_1+2𝑥_2\le22$$
# $$𝑥_1,𝑥_2≥0$$
#
# a. (5 ptos) Escriba el problema en su forma estándar, describiendo en forma explícita el vector $c^t$, la matriz $A$ y el vector $b$.
#
# b. (8 ptos) Muestre que la solución dada por las variables auxiliares (holgura ó superávit) es básica e infactible.
#
# c. (9 ptos) Considere el siguiente Tableau para el problema en su forma de minimización que definió en (a.) y que se encuentra incompleto. Encuentre los valores omitidos $\alpha,\beta,\gamma$, justificando en cada caso su respuesta.
#
# |Variable|$x_1$|$x_2$|$s_1$|$h_1$|$h_2$|$−z$|
# |:--:|:--:|:--:|:--:|:--:|:--:|:--:|
# |F. Objetivo|$0$|$-\frac{13}{5}$|$-\frac{1}{5}$|$\alpha$|$0$|$\gamma$|
# |$x_1$|$1$|$\frac{2}{5}$|$-\frac{1}{5}$|$0$|$0$|$\beta$|
# |$h_1$|$0$|$-\frac{16}{5}$|$\frac{3}{5}$|$1$|$0$|$0$|
# |$h_2$|$0$|$\frac{8}{5}$|$\frac{1}{5}$|0|1|16|
#
# d. (13 ptos) Para el Tableau definido en (c.), determine si ésta es la solución óptima del problema original. De no serlo, encuentre el óptimo del problema, especificando el valor de las variables básicas y el valor de la función objetivo.

# %%
#c. 0,6,6
#d. No, entra x2, sale h2. Sol (2,10) - obj 32

# %% [markdown]
# ### Ejercicio 25
#
# Considere el siguiente modelo de optimización lineal:
#
# $$ máx \quad 3x_1 + 2x_2$$
#
# sujeto a,
#
# $$− x_1 + x_2 \le 1$$
# $$5x_1 + 3x_2 \le 15$$
# $$x_2 \ge 1$$
# $$x_1, x_2 \ge 0$$
#
# a. Estandarice el modelo e indique la cantidad de posibles bases. Explique claramente su respuesta.
#
# b. Considere las siguientes 3 bases.
#
#   1. $B_1$, formada por las variables $x_1$, $x_3$ y $x_5$, siendo $x_5$ la variable auxiliar de la tercera restricción.
#   2. $B_2$, formada por las variables $x_2$, $x_3$ y $x_5$, siendo $x_5$ la variable auxiliar de la tercera restricción.
#   3. $B_3$, formada por las variables $x_2$, $x_4$ y $x_5$, siendo $x_4$ y $x_5$ las variables auxiliares de la segunda y tercera restricciones, respectivamente.
#
# Seleccione una base apropiada y realice una iteración completa del método simplex (en la forma que usted quiera). Para la base seleccionada y para la nueva base después de iterar indique claramente: valor de las variables básicas, valor de la función objetivo. Luego de hacer la iteración solicitada, indique y justifique si la base obtenida es o no óptima.
#
# c. Considere la base formada por las variables $x_1$, $x_2$ y $x_5$, con $x_5$ la variable auxiliar de la tercera restricción. Indique claramente el efecto que tendrá en cada variable básica el aumento de una unidad en el valor de $x_3$.

# %%
#b. B1 y B2 infactibles, B3 factible se itera ahi. Nueva base x2, x1 y x5 sol (5/2, 3/2, 3/2) opt: 19/2. c son -1/8 y -5/8 -> optimo
#c. x1 aumenta en 0.38, y x2 y x5 disminuyen en 0.625 unidades, respectivamente
