# %% [markdown]
# ## IIP314W Optimización aplicada a negocios
#
# Ejercicios modelamiento lineal, otros tipos de problemas.

# %% [markdown]
# Problemas multiperiodo: Este tipo de problemas busca un optimo que no sea instantaneo, sino que encuentra una solución que involucra periodos futuros.
#
# ### Ejercicio 6
#
# La empresa Chinchulancha, debe decidir cuantos botes de vela debe producir durante los cuatro trimestres del año. La demanda durante cada uno de los cuatro trimestres es la que sigue:
#
# | Periodo | Demanda botes de vela |
# |:-------:|:---------------------:|
# | 1 | 60 |
# | 2 | 30 |
# | 3 | 50 |
# | 4 | 90 |
#
# Al comienzo del primer trimestre, Chinculancha tenía un inventario de 5 botes. La empresa debe decidir cuantos botes producirá durante cada trimestre. En cada trimestre se pueden producir hasta 40 botes con mano de obra regular, con un costo total de \\$400 dólares por bote, pero se puede producir más botes con mano de obra extra, en este caso, el costo del bote es de \\$450 dólares.
#
# Cada bote que se mantenga en el inventario tiene un costo de \\$20 dólares por trimestre. Modele un calendario de producción con el fin de minimizar los costos de producción e inventario durante los cuatro trimestres.

# %% [markdown]
# ### Solución
#
# - Parámetros:
#
#     - $t$ : [1,2,3,4]
#     - $d_t$ : [60, 30, 50, 90]
#
# - Variables de decisión:
#
#     - $r_t$ : Cantidad de botes a producir en el periodo $t$ con mano de obra regular. ($t = 1..4$)
#     - $e_t$ : Cantidad de botes a producir en el periodo $t$ con mano de obra extra.
#     - $i_t$ : Inventario al final del periodo $t$.
#
# - Restricciones
#
#     - Producción, Demanda, Inventario
#
#         $$ i_0 = 10 $$
#
#         $$ i_t = i_{t-1} + r_t + e_t - d_t $$
#
#     - Producción mano de obra regular
#
#         $$ r_t \le 40  $$
#
#     - No negatividad
#
# - Función Objetivo
#
# $$ Min \quad Costos = \sum_{t=1}^4 400 r_t + 450 e_t + 20 i_t$$
#
# Nota: Es logistico también.

# %% [markdown]
# Problemas de distribución o transporte: La idea es minimizar el costo de llevar un bien desde la fuente al destino.
#
# ### Ejercicio 7
#
# Una empresa energética chilena dispone de cuatro plantas de generación para satisfacer la demanda diaria eléctrica en cuatro ciudades, Santiago, Valparaíso, Concepción y Talca. Las plantas 1,2,3 y 4 pueden satisfacer 80, 30, 60 y 45 millones de KW al día respectivamente. Las necesidades de las ciudades de Santiago, Valparaíso, Concepción y Talca son de 70, 40, 70 y 35 millones de Kw al día respectivamente. Los costos asociados al envío de suministro energético por cada millón de KW entre cada planta y cada ciudad son los registrados en la siguiente tabla.
#
#
# |  | Santiago | Valparaíso | Concepción | Talca |
# |:--|:---:|:---:|:---:|:---:|
# | Planta 1 | 5 | 2 | 7 | 3 |
# | Planta 2 | 3 | 6 | 6 | 1 |
# | Planta 3 | 6 | 1 | 2 | 4 |
# | Planta 4 | 4 | 3 | 6 | 6 |
#
# Formule un modelo de programación lineal que permita satisfacer las necesidades de todas las ciudades al tiempo que minimice los costos asociados al transporte.

# %% [markdown]
# ### Ejercicio 8 (certamen 1 industrial)
#
# Una empresa comercializadora de frutas congeladas tiene $i$ productos distintos. Actualmente tiene $B_i$ toneladas de fruta $i$ almacenadas en sus cámaras frigoríficas. La empresa desea planificar las ventas de frutas para las siguientes $t$ semanas. En semana $t$ la demanda local de fruta $i$ será $D_{it}$ y el beneficio neto por tonelada vendida será $L_{it}$ pesos. Por otro lado, puede vender al mercado internacional, donde el beneficio de neto esperado para la semana $t$ es $I_{it}$ pesos por tonelada. No hay límite a la demanda internacional, pero puede enviar como máximo F toneladas de fruta cada semana por barco.
#
# Considerando que el costo de almacenar en frío una tonelada de fruta $i$ de una semana a la siguiente es de $A_i$ pesos, formule un modelo de programación lineal que maximice la utilidad de la empresa.

# %% [markdown]
# ### Adelanto
# Problemas optimización lineal mixto (variables continua y binaria)
#
# ### Ejercicio 11
#
# Una empresa europea piensa instalar plantas de producción en Chile para lanzar sus productos al mercado chileno por lo que necesita decidir su plan de producción para el próximo ano. La empresa puede fabricar $N$ productos distintos y la elaboración de cada uno de ellos implica la compra de una máquina especializada para su elaboración a un costo de $f_n$.
#
# Además, el costo variable de producir una unidad del producto $n$ es de $c_n$. Así, si se decide elaborar el producto $n$ se deberá necesariamente incurrir en un costo de $f_n$ más los costos variables por elaboración del producto y si se decide no fabricarlo no se incurrirá en ningún tipo de gasto.
#
# Si la demanda pronosticada para el producto $n$ es de $D_n$ unidades (n=1...N) pudiendo venderse dicho producto a un precio de $p_n$, formule un PPL mixto que resuelva el problema de encontrar el conjunto de productos que la empresa debe fabricar.
