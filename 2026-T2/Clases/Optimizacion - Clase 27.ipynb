# %% [markdown]
# ## IIP314W Optimización aplicada a negocios
#
# Simplex dual, repaso certamen 2 (pregunta 3)

# %% [markdown]
# ### Ejercicio 26
#
# En un taller se producen sillas ($𝑥_1$), mesas ($𝑥_2$) y cómodas de ($𝑥_3$). Para el próximo periodo, el taller ha planificado su producción de acuerdo con el siguiente modelo **P**:
#
# $$ máx \quad 10 x_1 + 40 x_2 + 35 x_3 $$
#
# sujeto a las siguientes restricciones,
#
# R1. $\quad 2x_1+10x_2+25x_3 \le 200$
#
# R2. $\quad 2x_1+5x_2+5x_3 \le 120$
#
# R3. $\quad x_1+4x_2+5x_3 \le 230$
#
# R4. $\quad x_1 \ge 10$
#
# R5. $\quad x_2 \ge 4$
#
# R6. $\quad x_3 \ge 2$
#
#
# Con variables $x_1,x_2,x_3 \ge 0$. (R1) representa la disponibilidad de madera, (R2) la de barriles de pintura y (R3) la de tubos de pegamento. Las restricciones (R4), (R5) y (R6) representan ventas comprometidas para cada producto. La función objetivo representan la utilidad por las unidades producidas.
# La solución óptima de **P** indica que el taller debe producir 35 sillas, 8 mesas y 2 cómodas.
#
# a. (5p) Plantee el problema dual de **P**
#
# b. (15p) Encuentre la solución del problema planteado en el ítem (a)
#
# c. (7p) De una tienda le ofrecen más madera, pintura y pegamento ¿Cuánto está dispuesto a pagar por cada unidad de insumos adicionales? Explique.
#
# d. (8p) ¿Cuánto debería subir el precio de las cómodas para que cambie la producción óptima actual? Muestre todos sus cálculos

# %%
#b. y1 = 3, y2 = 2, y6 = 50
#c. madera adicional hasta $3, pintura adicional hasta $2. Nada por pegamento.
#d. 50, de 35 a 85

# %% [markdown]
# ### Ejercicio 27
#
# La empresa *Otto Kraus* fabrica tres tipos de juguetes: trenes, camiones y autos. Para fabricarlos, tiene tres máquinas de ensamblajes (llamémoslas máquina 1, máquina 2 y máquina 3), cuyas disponibilidades de tiempo diario son de 430, 460 y 420 minutos. Se tiene, además, la siguiente información respecto a los tiempos de ensamblaje de cada juguete y su precio de venta unitario.
#
# | Tipo de juguete | Máquina 1 | Máquina 2 | Máquina 3 | Precio de venta |
# |:---|:---:|:---:|:---:|:---:|
# |Tren |1 |3 |1 |3|
# |Camión |2 |0 |4 |2|
# |Auto |1 |2 |0 |5|
#
# Si $x_1$ es la cantidad de trenes vendidos, $x_2$ es la cantidad de camiones vendidos y $x_3$ es la cantidad de autos vendidos, un modelo de programación lineal está dado por:
#
# $$máx \quad 3x_1 + 2x_2 + 5x_3$$
#
# sujeto a,
#
# $$x_1 + 2x_2 + x_3 \le 430$$
# $$3x_1 + 2x_3 \le 460$$
# $$x_1 + 4x_2 \le 420$$
# $$x_1, x_2, x_3 \ge 0$$
#
# Se puede verificar que la solución óptima está dada por producir 100 camiones, 230 autos y 0 trenes (no es necesario que lo verifique).
#
# a. Plantee el problema dual.
#
# b. Encuentre la solución del problema dual.
#
# c. Usando la información obtenida en ítem anterior, determine cuánto está dispuesto a pagar por cada minuto adicional de uso de cada una de las máquinas.
#
# d. Un día en particular, la máquina 2 necesita ser limpiada y eso reduce en 15 minutos su tiempo de disponibilidad. Haciendo un análisis de sensibilidad, determine si esto hace que sea conveniente empezar a producir trenes.
#
# e. Determine cuál debiera ser el valor unitario de venta mínimo de los trenes para que sea conveniente empezar a producirlos.

# %%
#b. y1=1, y2=2, y3=0.
#c. m1 hasta 1, m2 hasta 2 y m3 nada.
#d. b2 ≥ 440, como se reduce a 445, no se produce trenes
#e. al menos 7.
